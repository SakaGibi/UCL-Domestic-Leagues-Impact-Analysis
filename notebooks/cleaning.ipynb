# %%
import pandas as pd
import os

# %% [markdown]
# cleaning the 'results' column from NaN values

# %%
all_matches = pd.read_csv("../data/processed/all_matches_raw.csv")

# Drop NA values
all_matches = all_matches.dropna(subset=['result'])
print(all_matches.tail())

all_matches.to_csv("../data/processed/all_matches_cleaned.csv", index=False)
# Out:
#             home_team       away_team              date       competition  \
# 13774       Liverpool           Paris  14/04/2026 19:00  Champions_League
# 13775         Arsenal     Sporting CP  15/04/2026 19:00  Champions_League
# 13776  Bayern München     Real Madrid  15/04/2026 19:00  Champions_League
# 13777           Paris  Bayern München  28/04/2026 19:00  Champions_League
# 13778          Atleti         Arsenal  29/04/2026 19:00  Champions_League
#
#            stage     season  is_after_ucl result  home_goals  away_goals  \
# 13774  QF Game 2  2025-2026           NaN  0 - 2         NaN         NaN
# 13775  QF Game 2  2025-2026           NaN  0 - 0         NaN         NaN
# 13776  QF Game 2  2025-2026           NaN  4 - 3         NaN         NaN
# 13777  SF Game 1  2025-2026           NaN  5 - 4         NaN         NaN
# 13778  SF Game 1  2025-2026           NaN  1 - 1         NaN         NaN
#
#        points  ucl_format  home_team_match_count  away_team_match_count  \
# ...
